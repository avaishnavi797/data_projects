# %% [markdown]
# ### Importing required libraries

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.sparse import csr_matrix

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
from recommenders.knn_recommender import Recommender
# Out:
# /usr/local/lib/python3.12/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# mkdir -p ~/.kaggle && echo KGAT_6f4c5cd2ac3e4b6b1e83e772be23fbbf > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token

# %%
import json, os

# Your Kaggle credentials
kaggle_username = "vaishnavi9924"
kaggle_key = "KGAT_129d3e29e0832f33659e73dd52e057d3"

# Ensure directory exists
os.makedirs(os.path.expanduser("~/.kaggle"), exist_ok=True)

# Write JSON properly
with open(os.path.expanduser("~/.kaggle/kaggle.json"), "w") as f:
    json.dump({"username": kaggle_username, "key": kaggle_key}, f)

# Set permissions
os.chmod(os.path.expanduser("~/.kaggle/kaggle.json"), 0o600)

# %%
# !ls -l ~/.kaggle/
# Out:
# total 8
# -rw------- 1 root root 38 Jul 10 14:07 access_token
# -rw------- 1 root root 77 Jul 10 14:39 kaggle.json

# %%
# !cat ~/.kaggle/kaggle.json
# Out:
# {"username": "vaishnavi9924", "key": "KGAT_129d3e29e0832f33659e73dd52e057d3"}

# %%
# !kaggle datasets list -s million-song
# Out:
# ref                                                      title                                                    size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  -------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# notshrirang/spotify-million-song-dataset                 Spotify Million Song Dataset                         21735868  2022-11-21 16:48:45.780000          23829        155                1
# undefinenull/million-song-dataset-spotify-lastfm         Million Song Dataset + Spotify + Last.fm            670020079  2023-04-22 08:17:45.377000           8688         78        0.9411765
# thaisneubauer/million-song-dataset-studies               Million Song Dataset studies                           583738  2017-12-13 21:58:28.613000            764         16        0.7058824
# uciml/msd-audio-features                                 Audio features of songs ranging from 1922 to 2011   208801502  2017-09-06 19:24:41.820000           1889         79        0.8235294
# anuragbanerjee/million-song-data-set-subset              Million Song Data Set Subset                         62653826  2018-02-22 12:13:39.707000           3697         28       0.29411766
# nikhilnayak123/5-million-song-lyrics-dataset             5 Million Song Lyrics Dataset                      3316858407  2022-04-22 02:37:49.200000           2496         29        0.5294118
# joebeachcapital/57651-spotify-songs                      60000 Spotify Songs                                  21501186  2024-01-23 06:48:36.383000           2993         52                1
# amitanshjoshi/spotify-1million-tracks                    Spotify_1Million_Tracks                              80841459  2023-06-21 12:27:55.677000          10969        108                1
# alitaqishah/spotify-wrapped-2025-top-songs-and-artists   Spotify Wrapped 2025 | Top Songs & Artists               8564  2026-03-13 20:37:00.967000           4365        115                1
# edumucelli/spotifys-worldwide-daily-song-ranking         Spotify's Worldwide Daily Song Ranking               45167411  2018-01-12 20:32:57.537000          15291        366        0.7352941
# imsparsh/lakh-midi-clean                                 Lakh MIDI Dataset Clean                             236993171  2021-06-21 14:01:37.357000           8165         47            0.875
# ryanholbrook/the-million-songs-dataset                   The Million Song Dataset                            212451269  2020-08-03 16:57:33.240000            584          5        0.5882353
# carlosgdcj/genius-song-lyrics-with-language-information  Genius Song Lyrics                                 3263274583  2023-01-11 19:52:10.993000           9946        118        0.8235294
# figolm10/music-dataset                                   Spotify Million Songs Dataset                        21735868  2024-01-04 09:22:47.750000             38         15       0.29411766
# ziriantahirli/million-song-data-analysis-2               Million Song Data Analysis 2                         81159531  2024-06-29 12:32:25.833000             80          5       0.64705884
# joaorobson/pink-floyd-lyrics                             Pink Floyd Lyrics                                       36740  2020-01-24 15:19:13.923000            534         18       0.88235295
# arslanali4343/top-song-daily-ranking-of-spotifys          Top Song Daily Ranking Of Spotify's                 13913201  2020-10-01 15:24:59.907000            653         91        0.9411765
# sergeserbinenko/2-million-song-spotify-dataset           2 Million Song Spotify Dataset                      148531457  2023-04-10 08:44:51.910000            216          8            0.375
# bivanmallick/million-song-recoomendation                 The Million Songs Dataset                            61382410  2023-10-31 12:43:33.690000            203          4       0.64705884
# thedevastator/popularity-of-spotify-top-tracks-by-genre  Popularity of Spotify Top Tracks by Genre             9324456  2022-10-18 17:55:53.270000           1599         42        0.8235294

# %%
# !pip install --upgrade kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (2.2.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.4.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.19.4)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.30 in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.1.33)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.2.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (4.2.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle) (2026.6.17)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2026.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.10.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.15.0)

# %%
# !kaggle datasets download -d bivanmallick/million-song-recoomendation
# Out:
# Dataset URL: https://www.kaggle.com/datasets/bivanmallick/million-song-recoomendation
# License(s): other
# Downloading million-song-recoomendation.zip to /content
# 100% 58.5M/58.5M [00:01<00:00, 54.9MB/s]

# %%
# !unzip million-song-recoomendation.zip
# Out:
# Archive:  million-song-recoomendation.zip
#   inflating: song_data.csv
#   inflating: triplets_file.csv

# %% [markdown]
# ### Reading the files

# %%
import pandas as pd
user_info = pd.read_csv('triplets_file.csv')
user_info.columns = ['user_id', 'song_id', 'listen_count']

# %%
user_info.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1

# %%
import pandas as pd
song_info = pd.read_csv('song_data.csv')
song_info.drop_duplicates(['song_id'], inplace=True)

# %%
song_info.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
songs = pd.merge(user_info, song_info, on="song_id", how="left")

# %%
songs.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
songs.to_csv('songs.csv', index=False)

# %%
df_songs = pd.read_csv('songs.csv')

# %% [markdown]
# ## Exploring the data

# %%
df_songs.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title                        release    artist_name  year
# 0         The Cove             Thicker Than Water   Jack Johnson     0
# 1  Entre Dos Aguas            Flamenco Para Niños  Paco De Lucia  1976
# 2         Stronger                     Graduation     Kanye West  2007
# 3   Constellations              In Between Dreams   Jack Johnson  2005
# 4     Learn To Fly  There Is Nothing Left To Lose   Foo Fighters  1999

# %%
df_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       object
#  1   song_id       object
#  2   listen_count  int64
#  3   title         object
#  4   release       object
#  5   artist_name   object
#  6   year          int64
# dtypes: int64(2), object(5)
# memory usage: 106.8+ MB

# %%
#Get total observations
print(f"There are {df_songs.shape[0]} observations in the dataset")
# Out:
# There are 2000000 observations in the dataset

# %% [markdown]
# Now, we should perform some cleaning steps. But looking at the dataset, we can see that there is no missing values.

# %%
df_songs.isnull().sum()
# Out:
# user_id         0
# song_id         0
# listen_count    0
# title           0
# release         0
# artist_name     0
# year            0
# dtype: int64

# %% [markdown]
# Let's start exploring some characteristics of the dataset:
#
# - Unique songs:

# %%
#Unique songs
unique_songs = df_songs['title'].unique().shape[0]
print(f"There are {unique_songs} unique songs in the dataset")
# Out:
# There are 9567 unique songs in the dataset

# %% [markdown]
# - Unique artists:

# %%
#Unique artists
unique_artists = df_songs['artist_name'].unique().shape[0]
print(f"There are {unique_artists} unique artists in the dataset")
# Out:
# There are 3375 unique artists in the dataset

# %% [markdown]
# - Unique users:

# %%
#Unique users
unique_users = df_songs['user_id'].unique().shape[0]
print(f"There are {unique_users} unique users in the dataset")
# Out:
# There are 76353 unique users in the dataset

# %% [markdown]
# We'll go ahead and explore the popularity of songs and artists.

# %% [markdown]
# ### Most popular songs

# %% [markdown]
# How do we determine which are the most popular songs? For this task, we'll count how many times each song appears. Note that while we are using  `listen_count`, we only care about the number of rows, we don't consider the number present in that row. This number represents how many times one user listen to the same song.

# %%
#count how many rows we have by song, we show only the ten more popular songs
ten_pop_songs = df_songs.groupby('title')['listen_count'].count().reset_index().sort_values(['listen_count', 'title'], ascending = [0,1])
ten_pop_songs['percentage']  = round(ten_pop_songs['listen_count'].div(ten_pop_songs['listen_count'].sum())*100, 2)

# %%
ten_pop_songs = ten_pop_songs[:10]
ten_pop_songs
# Out:
#                                                   title  listen_count  \
# 6836                                      Sehr kosmisch          8277
# 8725                                               Undo          7032
# 1964                     Dog Days Are Over (Radio Edit)          6949
# 9496                                     You're The One          6729
# 6498                                            Revelry          6145
# 6825                                            Secrets          5841
# 3437  Horn Concerto No. 4 in E flat K495: II. Romanc...          5385
# 2595                                          Fireflies          4795
# 3322                                   Hey_ Soul Sister          4758
# 8494                                           Tive Sim          4548
#
#       percentage
# 6836        0.41
# 8725        0.35
# 1964        0.35
# 9496        0.34
# 6498        0.31
# 6825        0.29
# 3437        0.27
# 2595        0.24
# 3322        0.24
# 8494        0.23

# %%
labels = ten_pop_songs['title'].tolist()
counts = ten_pop_songs['listen_count'].tolist()

# %%
plt.figure()
sns.barplot(x=counts, y=labels, palette='Set3')
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Most popular artist

# %% [markdown]
# For the next task, we'll count how many times each artist appears. Again, we'll count how many times the same artist appears.

# %%
#count how many rows we have by artist name, we show only the ten more popular artist
ten_pop_artists  = df_songs.groupby(['artist_name'])['listen_count'].count().reset_index().sort_values(['listen_count', 'artist_name'],
                                                                                                ascending = [0,1])

# %%
ten_pop_artists = ten_pop_artists[:10]
ten_pop_artists
# Out:
#                  artist_name  listen_count
# 649                 Coldplay         29422
# 2850          The Black Keys         19862
# 1651           Kings Of Leon         18747
# 1107  Florence + The Machine         18112
# 1370            Jack Johnson         17801
# 2946             The Killers         16063
# 2374               Radiohead         14890
# 736                Daft Punk         14715
# 2073                    Muse         14005
# 1554           Justin Bieber         13959

# %%
plt.figure()
labels = ten_pop_artists['artist_name'].tolist()
counts = ten_pop_artists['listen_count'].tolist()
sns.barplot(x=counts, y=labels, palette='Set2')
sns.despine(left=True, bottom=True)

# %% [markdown]
# ### Listen count by user

# %% [markdown]
# We can also get some other information from the feature `listen_count`. We will answer the folloging questions:

# %% [markdown]
# **What was the maximum time the same user listen to a same song?**

# %%
df_songs.groupby('user_id')['listen_count'].max().sort_values(ascending=False).head()
# Out:
# user_id
# d13609d62db6df876d3cc388225478618bb7b912    2213
# 50996bbabb6f7857bf0c8019435b5246a0e45cfd     920
# 5ea608df0357ec4fda191cb9316fe8e6e65e3777     879
# bb85bb79612e5373ac714fcd4469cabeb5ed94e1     796
# c012ec364329bb08cbe3e62fe76db31f8c5d8ec3     683
# Name: listen_count, dtype: int64

# %%
listen_counts = pd.DataFrame(df_songs.groupby('listen_count').size(), columns=['count'])

# %%
print(f"The maximum time the same user listened to the same songs was: {listen_counts.reset_index(drop=False)['listen_count'].iloc[-1]}")
# Out:
# The maximum time the same user listened to the same songs was: 2213

# %% [markdown]
# **How many times on average the same user listen to a same song?**

# %%
df_songs.groupby('user_id')['listen_count'].mean().sort_values(ascending=False).head()
# Out:
# user_id
# c16ca5938d2126e8533e4a01496e10544e2cbb9e    192.000000
# b85e44249a1d26a378c0757442452525ecfa1abf    126.700000
# 50996bbabb6f7857bf0c8019435b5246a0e45cfd    123.500000
# 38767872c514c1b43bab5c7b213b6702980d87c0    113.230769
# db10ea393c016bd15623273fe50295beb77d9bbd    113.000000
# Name: listen_count, dtype: float64

# %%
print(f"On average, a user listen to the same song {df_songs['listen_count'].mean()} times")
# Out:
# On average, a user listen to the same song 3.0454845 times

# %% [markdown]
# We can also check the distribution of `listen_count`:

# %%
plt.figure(figsize=(20, 5))
sns.boxplot(x='listen_count', data=df_songs)
# Out:
# <Axes: xlabel='listen_count'>

# %% [markdown]
# **What are the most frequent number of times a user listen to the same song?**

# %%
listen_counts_temp = listen_counts[listen_counts['count'] > 50].reset_index(drop=False)

# %%
plt.figure(figsize=(16, 8))
sns.barplot(x='listen_count', y='count', palette='Set3', data=listen_counts_temp)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show();

# %% [markdown]
# **How many songs does a user listen in average?**

# %%
song_user = df_songs.groupby('user_id')['song_id'].count()

# %%
plt.figure(figsize=(16, 8))
sns.distplot(song_user.values, color='orange')
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show();
# Out:
# /tmp/ipykernel_864/2530348831.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(song_user.values, color='orange')

# %%
print(f"A user listens to an average of {np.mean(song_user)} songs")
# Out:
# A user listens to an average of 26.194124657839247 songs

# %%
print(f"A user listens to an average of {np.median(song_user)} songs, with minimum {np.min(song_user)} and maximum {np.max(song_user)} songs")
# Out:
# A user listens to an average of 16.0 songs, with minimum 1 and maximum 711 songs

# %% [markdown]
# We can see that a user listens in average to 27 songs. Even the maximum amount of songs listen by an user is 711, and we have 9567 songs in our dataset.
#
# So, not all user listen to all songs, so a lot of values in the `song x users` matrix are going to be zero. Thus, we’ll be dealing with extremely sparse data.
#
# *How sparse?* Let's check that:

# %%
# Get how many values should it be if all songs have been listen by all users
values_matrix = unique_users * unique_songs

# %%
# Substract the total values with the actural shape of the DataFrame songs
zero_values_matrix = values_matrix - df_songs.shape[0]

# %%
print(f"The matrix of users x songs has {zero_values_matrix} values that are zero")
# Out:
# The matrix of users x songs has 728469151 values that are zero

# %% [markdown]
# Dealing with such a sparse matrix, we'll take a lot of memory and resources. To make our life easier, let's just select all those users that have listened to at least 16 songs.

# %% [markdown]
# ### Prepare the data

# %%
# Get users which have listen to at least 16 songs
song_ten_id = song_user[song_user > 16].index.to_list()

# %%
# Filtered the dataset to keep only those users with more than 16 listened
df_song_id_more_ten = df_songs[df_songs['user_id'].isin(song_ten_id)].reset_index(drop=True)

# %% [markdown]
# We need now to work with a `scipy-sparse matrix` to avoid overflow and wasted memory. For that purpose, we'll use the `csr_matrix` function from `scipy.sparse`.

# %%
# convert the dataframe into a pivot table
df_songs_features = df_song_id_more_ten.pivot(index='song_id', columns='user_id', values='listen_count').fillna(0)

# obtain a sparse matrix
mat_songs_features = csr_matrix(df_songs_features.values)

# %% [markdown]
# Let's take a look at the table `user x song`.

# %%
df_songs_features.head()
# Out:
# user_id             000e2c2a8c7870ff9121f212b35c8b3a20cc0e67  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             000ebc858861aca26bac9b49f650ed424cf882fc  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             000ef25cc955ad5841c915d269432eea41f4a1a5  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             0012bf75d43a724f62dc746d9e85ae0088a3a1d6  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             001322829b5dc3edc59bf78189617ddd8f23c82a  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             00185e316f07f0f00c325ca034be59c15b362401  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             0019740e3e8c24e223a6f88e3faa7c144ec5a014  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             001b005fe5e80d3cb45f320f5658fc8e2e72794e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             001f22c638730aed5659034c447d3cf0e658898e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             0021d9a4628624f6d70237f9c200ab82e766bf26  ...  \
# song_id                                                       ...
# SOAAAGQ12A8C1420C8                                       0.0  ...
# SOAACPJ12A81C21360                                       0.0  ...
# SOAACSG12AB018DC80                                       0.0  ...
# SOAAEJI12AB0188AB5                                       0.0  ...
# SOAAFAC12A67ADF7EB                                       0.0  ...
#
# user_id             fff300cd094fe04030b79fae550dc9d065190182  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fff4676dacb2e9a7217702f62ee70e88aa512ecc  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fff4e1a7dacbe9c13051c08f09bf66d76cbee35e  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fff543db7918cb8f4f56f7470903eb2f1d5a6dd8  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fff6c30c773e6ffafcac213c9afd9666afaf6d63  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fffb701ee87a32eff67eb040ed59146121f01571  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fffc0df75a48d823ad5abfaf2a1ee61eb1e3302c  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fffce9c1537fbc350ea68823d956eaa8f5236dbe  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fffd9635b33f412de8ed02e44e6564e3644cf3c6  \
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# user_id             fffea3d509760c984e7d40789804c0e5e289cc86
# song_id
# SOAAAGQ12A8C1420C8                                       0.0
# SOAACPJ12A81C21360                                       0.0
# SOAACSG12AB018DC80                                       0.0
# SOAAEJI12AB0188AB5                                       0.0
# SOAAFAC12A67ADF7EB                                       0.0
#
# [5 rows x 36561 columns]

# %% [markdown]
# Because the system will output the id of the song, instead of the title, we'll make a function that maps those indices with the song title.

# %%
df_unique_songs = df_songs.drop_duplicates(subset=['song_id']).reset_index(drop=True)[['song_id', 'title']]

# %%
decode_id_song = {
    song: i for i, song in
    enumerate(list(df_unique_songs.set_index('song_id').loc[df_songs_features.index].title))
}

# %% [markdown]
# ### Model and recommendations

# %% [markdown]
# So, we know that we want to use the model to predict songs. For that, we'll use the `Recommender` class wrote in the `knn_recommender` file.

# %%
model = Recommender(metric='cosine', algorithm='brute', k=20, data=mat_songs_features, decode_id_song=decode_id_song)

# %%
song = 'I believe in miracles'

# %%
new_recommendations = model.make_recommendation(new_song=song, n_recommendations=10)
# Out:
# Starting the recommendation process for I believe in miracles ...
# ... Done

# %%
print(f"The recommendations for {song} are:")
print(f"{new_recommendations}")
# Out:
# The recommendations for I believe in miracles are:
# ['Nine Million Bicycles', 'If You Were A Sailboat', 'Shy Boy', 'I Cried For You', "Spider's Web", 'Piece By Piece', 'On The Road Again', 'Blues In The Night', 'Blue Shoes', 'Thank You Stars']
